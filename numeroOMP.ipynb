# %%
import pandas as pd
import re

# %%
with open('OMP.txt','r') as file:
    omp=file.readlines()

# %%
tw=pd.read_excel('metadatos_losada_c.xlsx',index_col=None)

# %%
len(omp)
# Out:
# 121

# %%
linea=omp[0]

# %%
linea
# Out:
# '81093069 ACERCA DEL ALMA (O.M.P.48) ARISTOTELES 9500393069 $ 1,800.00\n'

# %%
num,isbn=extrac.group(1),extrac.group(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 num,isbn=extrac.group(1),extrac.group(3)
#
# NameError: name 'extrac' is not defined

# %%
num

# %%
isbn

# %%
dic={}
for linea in omp:
    try:
        extrac=re.search(r'.*O.M.P.(\d\d?\d?)(.*) ([0-9]*) ',linea)
        num,isbn=extrac.group(1),extrac.group(3)
        dic[isbn]=num
    except:
        pass

# %%
dic
# Out:
# {'9500393069': '48',
#  '9789500398022': '105',
#  '9500378302': '16',
#  '9789500393225': '58',
#  '9500393751': '4',
#  '9789500378390': '63',
#  '9500378434': '57',
#  '9500378345': '29',
#  '9789500393393': '47',
#  '9789500393911': '70',
#  '9500393816': '71',
#  '9500392720': '41',
#  '9789500392983': '53',
#  '9789500395816': '86',
#  '9789500392181': '14',
#  '9789500394215': '76',
#  '9789500378208': '31',
#  '9789500392532': '12',
#  '9500393735': '68',
#  '9500393050': '45',
#  '9789500393379': '49',
#  '9500394185': '77',
#  '9789500392198': '27',
#  '9789500394192': '75',
#  '9789500394840': '78',
#  '9789500393232': '59',
#  '9789500395854': '8',
#  '9789500378185': '11',
#  '9789500393072': '50',
#  '9789500395564': '81',
#  '9789500392914': '42',
#  '9789500392730': '32',
#  '9789500395700': '84',
#  '9500393964': '69',
#  '9789500392167': '24'}

# %%
tw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 967 entries, 0 to 966
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           967 non-null    int64
#  1   EAN                  967 non-null    int64
#  2   titulo               967 non-null    object
#  3   editorial            967 non-null    object
#  4   titulo_descripcion   967 non-null    object
#  5   sinopsis             967 non-null    object
#  6   alto                 967 non-null    float64
#  7   ancho                967 non-null    float64
#  8   dimension            967 non-null    object
#  9   coleccion            962 non-null    object
#  10  Número_de_colección  0 non-null      float64
#  11  formato_1            967 non-null    object
#  12  formato_2            967 non-null    object
#  13  Tipo_de_edicion      0 non-null      float64
#  14  idioma               967 non-null    object
#  15  idioma_ori           0 non-null      float64
#  16  autor                951 non-null    object
#  17  traductor            525 non-null    object
#  18  ilustrador           15 non-null     object
#  19  paginas              967 non-null    int64
#  20  extranjero           0 non-null      float64
#  21  bolsillo             967 non-null    object
#  22  edad                 0 non-null      float64
#  23  ibic                 967 non-null    object
# dtypes: float64(7), int64(3), object(14)
# memory usage: 181.4+ KB

# %%
for isbn,num in dic.items():
    if len(isbn)<12:
        isbn='978'+isbn
    try:
        index=tw[tw["EAN"]==int(isbn[:-1])].index[0]
        tw['Número_de_colección'].iat[index]=num
    except:
        pass

# %%
tw[tw['Número_de_colección'].notnull()]
# Out:
#      Unnamed: 0           EAN                  titulo editorial  \
# 10           11  978950039306         Acerca del alma    Losada
# 41           44  978950039802           El Anticristo    Losada
# 70           73  978950037830    El arte de la guerra    Losada
# 135         139  978950039322           Cartas persas    Losada
# 172         176  978950039375             Confesiones    Losada
# 887           sinopsis  “El hombre nace cuando surge como sujeto, cuan...
# 937           sinopsis  Utopía en la ficción histórica de Moro, es lo ...
#
#      alto  ancho dimension                                     coleccion  ...  \
# 10   21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 41   22.0   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 70   21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 135  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 172  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 199  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 244  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 275  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 302  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 327  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 353  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 391  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 395  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 396  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 397  22.0   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 487  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 501  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 547  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 568  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 593  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 630  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 667  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 721  22.0   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 748  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 760  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 770  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 825  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 858  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 865  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 881  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 887  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
# 937  21.5   14.0        cm  Biblioteca de Obras Maestras del Pensamiento  ...
#
#       idioma idioma_ori                   autor                   traductor  \
# 10   Español        NaN                     NaN                    Azcárate
# 41   Español        NaN    Nietzsche, Friedrich                Román Setton
# 70   Español        NaN     Maquiavelo, Nicolás              Marta Vassallo
# 135  Español        NaN             Montesquieu            Graciela Isnardi
# 172  Español        NaN             San Agustín           Silvia Magnavacca
# 199  Español        NaN          Kant, Immanuel                         NaN
# 244  Español        NaN        Alighieri, Dante                     Azevedo
# 275  Español        NaN         Descartes, René       José Rovira Armengol,
# 302  Español        NaN    Nietzsche, Friedrich         Gerardo R. Wehinger
# 327  Español        NaN        Ingenieros, José                         NaN
# 353  Español        NaN                 Plotino     Juan David García Bacca
# 391  Español        NaN  García Morente, Manuel                         NaN
# 395  Español        NaN                     NaN                    Azcárate
# 396  Español        NaN                     NaN                    Azcárate
# 397  Español        NaN    Schopenhauer, Arthur                         NaN
# 487  Español        NaN                     NaN                         NaN
# 501  Español        NaN       Sartre, Jean-Paul               Manuel Lamana
# 547  Español        NaN           Jaspers, Karl          J. Rovira Armengol
# 568  Español        NaN          Hobbes, Thomas                 Carlos Moya
# 593  Español        NaN                     NaN                    Azcárate
# 630  Español        NaN                     NaN              Luis Echávarri
# 667  Español        NaN     Dionisio Areopagita          Pablo A. Cavallero
# 721  Español        NaN           Marco Aurelio           Nicolás Estevanez
# 748  Español        NaN        Dilthey, Wilhelm               Elsa Tabernig
# 760  Español        NaN     Maquiavelo, Nicolás           Roberto Raschella
# 770  Español        NaN       Sartre, Jean-Paul            Aurora Bernárdez
# 825  Español        NaN       Sartre, Jean-Paul                 Juan Valmar
# 858  Español        NaN          Gebhardt, Carl                 Oscar Cohan
# 865  Español        NaN         Durkheim, Émile               Manuel Arranz
# 881  Español        NaN      Kierkegaard, Sören              Jaime Grinberg
# 887  Español        NaN       Romero, Francisco                         NaN
# 937  Español        NaN             Moro, Tomás  María Guillermina Nicolini
#
#     ilustrador  paginas extranjero bolsillo edad  ibic
# 10         NaN      236        NaN    Trade  NaN    HP
# 41         NaN      152        NaN    Trade  NaN    HP
# 70         NaN      224        NaN    Trade  NaN    HP
# 135        NaN      904        NaN    Trade  NaN    HP
# 172        NaN      448        NaN    Trade  NaN    HP
# 199        NaN      368        NaN    Trade  NaN    HP
# 244        NaN      192        NaN    Trade  NaN    HP
# 275        NaN      152        NaN    Trade  NaN    HP
# 302        NaN      176        NaN    Trade  NaN    HP
# 327        NaN      288        NaN    Trade  NaN    HP
# 353        NaN      224        NaN    Trade  NaN    HP
# 391        NaN      376        NaN    Trade  NaN    HP
# 395        NaN      216        NaN    Trade  NaN    HP
# 396        NaN      416        NaN    Trade  NaN    HP
# 397        NaN      288        NaN    Trade  NaN    HP
# 487        NaN      368        NaN    Trade  NaN    HP
# 501        NaN      272        NaN    Trade  NaN    HP
# 547        NaN      176        NaN    Trade  NaN    HP
# 568        NaN      576        NaN    Trade  NaN    HP
# 593        NaN      180        NaN    Trade  NaN    HP
# 630        NaN      168        NaN    Trade  NaN    HP
# 667        NaN      400        NaN    Trade  NaN    HP
# 721        NaN      192        NaN    Trade  NaN    HP
# 748        NaN      320        NaN    Trade  NaN    HP
# 760        NaN      216        NaN    Trade  NaN    HP
# 770        NaN      296        NaN    Trade  NaN    HP
# 825        NaN      864        NaN    Trade  NaN    HP
# 858        NaN      176        NaN    Trade  NaN    HP
# 865        NaN      448        NaN    Trade  NaN    HP
# 881        NaN      152        NaN    Trade  NaN    HP
# 887        NaN      376        NaN    Trade  NaN    HP
# 937        NaN      208        NaN    Trade  NaN    HP
#
# [32 rows x 24 columns]

# %%
tw.to_excel('metadatos_losada_c.xlsx',index=False)
